# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

# %%
data_train_path = 'training_set'
data_test_path = 'testing_set'
data_val_path = 'validation_set'

# %%
img_width = 180
img_height = 180

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle=True,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False)

# %%
data_cat = data_train.class_names

# %%
data_cat

# %%
data_val = tf.keras.utils.image_dataset_from_directory(
    data_val_path,
    shuffle=False,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False)
# Out:
# Found 30 files belonging to 4 classes.

# %%
data_test = tf.keras.utils.image_dataset_from_directory(
    data_test_path,
    shuffle=False,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False)
# Out:
# Found 25 files belonging to 4 classes.

# %%
plt.figure(figsize=(10,10))
for image, labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_cat[labels[i]])
        plt.axis('off')

# %%
from tensorflow.keras.models import Sequential

# %%
data_train
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
model = Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16,3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32,3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64,3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(len(data_cat))
])

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
epochs_size= 100
history = model.fit(data_train, validation_data=data_val, epochs=epochs_size)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 406ms/step - accuracy: 0.1857 - loss: 5.2423 - val_accuracy: 0.3333 - val_loss: 3.7983
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - accuracy: 0.4143 - loss: 2.4989 - val_accuracy: 0.1667 - val_loss: 1.9451
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.2000 - loss: 1.5295 - val_accuracy: 0.1000 - val_loss: 1.4006
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 0.3286 - loss: 1.3337 - val_accuracy: 0.3333 - val_loss: 1.1943
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.3714 - loss: 1.2429 - val_accuracy: 0.3333 - val_loss: 1.2672
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.4286 - loss: 1.1981 - val_accuracy: 0.4333 - val_loss: 1.2926
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 0.6000 - loss: 1.1198 - val_accuracy: 0.4000 - val_loss: 1.3521
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 0.6714 - loss: 1.0191 - val_accuracy: 0.3667 - val_loss: 1.6380
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - accuracy: 0.4571 - loss: 1.0103 - val_accuracy: 0.4000 - val_loss: 1.2073
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.6714 - loss: 0.8712 - val_accuracy: 0.3000 - val_loss: 1.5165
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.7286 - loss: 0.7385 - val_accuracy: 0.3333 - val_loss: 1.7322
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.7714 - loss: 0.6648 - val_accuracy: 0.3667 - val_loss: 1.6328
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 0.7714 - loss: 0.6238 - val_accuracy: 0.3667 - val_loss: 1.8917
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.8000 - loss: 0.5290 - val_accuracy: 0.2333 - val_loss: 2.1189
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - accuracy: 0.8429 - loss: 0.4633 - val_accuracy: 0.4000 - val_loss: 1.7304
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 0.9000 - loss: 0.3622 - val_accuracy: 0.5333 - val_loss: 1.5636
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 0.9143 - loss: 0.3232 - val_accuracy: 0.3667 - val_loss: 2.0184
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9000 - loss: 0.2734 - val_accuracy: 0.1667 - val_loss: 3.3953
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 228ms/step - accuracy: 0.8286 - loss: 0.4217 - val_accuracy: 0.4667 - val_loss: 1.7468
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 0.9429 - loss: 0.2549 - val_accuracy: 0.4667 - val_loss: 2.1696
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 0.
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 1.0000 - loss: 6.3402e-04 - val_accuracy: 0.4333 - val_loss: 3.9805
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 1.0000 - loss: 7.1511e-04 - val_accuracy: 0.4667 - val_loss: 4.0265
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 1.0000 - loss: 4.9089e-04 - val_accuracy: 0.4667 - val_loss: 4.0607
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 1.0000 - loss: 6.0940e-04 - val_accuracy: 0.4667 - val_loss: 4.0904
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 5.3731e-04 - val_accuracy: 0.4667 - val_loss: 4.1196
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - accuracy: 1.0000 - loss: 6.2251e-04 - val_accuracy: 0.4667 - val_loss: 4.1266
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 226ms/step - accuracy: 1.0000 - loss: 8.6894e-04 - val_accuracy: 0.4667 - val_loss: 4.0789
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - accuracy: 1.0000 - loss: 5.1420e-04 - val_accuracy: 0.5000 - val_loss: 4.0446
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 1.0000 - loss: 5.0637e-04 - val_accuracy: 0.4333 - val_loss: 4.0149
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 226ms/step - accuracy: 1.0000 - loss: 6.0060e-04 - val_accuracy: 0.4333 - val_loss: 3.9977
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 227ms/step - accuracy: 1.0000 - loss: 5.7537e-04 - val_accuracy: 0.4667 - val_loss: 3.9918
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 1.0000 - loss: 6.0118e-04 - val_accuracy: 0.4667 - val_loss: 3.9942
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 209ms/step - accuracy: 1.0000 - loss: 4.2188e-04 - val_accuracy: 0.4667 - val_loss: 4.0043
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 212ms/step - accuracy: 1.0000 - loss: 6.8958e-04 - val_accuracy: 0.5000 - val_loss: 4.0124
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 1.0000 - loss: 5.8709e-04 - val_accuracy: 0.5333 - val_loss: 4.0239
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - accuracy: 1.0000 - loss: 4.7149e-04 - val_accuracy: 0.5333 - val_loss: 4.0401
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 1.0000 - loss: 5.2037e-04 - val_accuracy: 0.5000 - val_loss: 4.0500
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 5.4619e-04 - val_accuracy: 0.5333 - val_loss: 4.0408
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 3.2756e-04 - val_accuracy: 0.5333 - val_loss: 4.0339
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - accuracy: 1.0000 - loss: 3.9206e-04 - val_accuracy: 0.5333 - val_loss: 4.0313
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 1.0000 - loss: 5.3002e-04 - val_accuracy: 0.5000 - val_loss: 4.0305
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 236ms/step - accuracy: 1.0000 - loss: 4.4986e-04 - val_accuracy: 0.5000 - val_loss: 4.0253
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 5.0506e-04 - val_accuracy: 0.5000 - val_loss: 4.0131
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 1.0000 - loss: 3.9061e-04 - val_accuracy: 0.5000 - val_loss: 4.0094
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 1.0000 - loss: 4.2316e-04 - val_accuracy: 0.5000 - val_loss: 4.0141
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 1.0000 - loss: 5.1591e-04 - val_accuracy: 0.5000 - val_loss: 4.0226

# %%
epochs_range = range(epochs_size)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label = 'Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'],label = 'Validation Accuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label = 'Training Loss')
plt.plot(epochs_range, history.history['val_loss'],label = 'Validation Loss')
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
image = 'training_set/Not a diabetic wound/IMG_7233.JPG'
image = tf.keras.utils.load_img(image, target_size=(img_height,img_width))
img_arr = tf.keras.utils.array_to_img(image)
img_bat = tf.expand_dims(img_arr,0)

# %%
predict = model.predict(img_bat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step

# %%
score = tf.nn.softmax(predict)

# %%
print('Wound in image is {} with an accuracy of 95%'.format(data_cat[np.argmax(score)],np.max(score)*100))
# Out:
# Wound in image is Not a diabetic wound with accuracy of 95%

# %%
model.save('Wound_classify.keras')
